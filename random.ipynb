# %%
from numpy import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = random.randint(20,100) #randint(from, till)
y = random.rand() #lower than 1 and biger than 0
print(x)
print(y)
# Out:
# 46
# 0.7034615687398706

# %%
x = random.randint(100,size=(5))
y = random.randint(100,size=(5,3))
z = random.rand(5)
print(x)
print("===")
print(y)
print("===")
print(z)
# Out:
# [95 18 29 72 64]
# ===
# [[ 4 69 69]
#  [52 99 96]
#  [96 57 78]
#  [42 57 59]
#  [34 20 29]]
# ===
# [0.83619394 0.05949992 0.6892485  0.16444253 0.70494851]

# %%
x = random.choice([1,2,3,4,5])
y = random.choice([1,2,3,4,5], size=(5))
print(x)
print(y)
# Out:
# 4
# [4 5 2 1 5]

# %% [markdown]
# DATA DISTRIBUTION

# %%
array = [1, 2, 3, 4]
x = random.choice(array,p=[0.1, 0.3, 0.6, 0.0],size=(100))
print(x)
# Out:
# [3 2 3 2 3 3 2 2 3 3 3 2 2 3 3 3 1 3 3 3 1 3 1 3 1 2 2 3 3 2 3 3 3 3 2 2 3
#  2 1 3 2 3 3 1 3 3 3 3 3 2 1 3 3 3 3 3 1 3 3 3 1 3 3 2 3 3 2 2 2 3 2 2 1 2
#  2 2 2 3 2 3 3 3 2 3 3 3 3 3 2 3 3 3 3 3 3 3 3 2 2 3]

# %% [markdown]
# RANDOM PERMUTATION

# %%
arr = np.array([1, 2, 3, 4, 5])
arr2 = np.array([1, 2, 3, 4, 5])
random.shuffle(arr2)
print(arr2)
print(random.permutation(arr))
# Out:
# [3 4 2 1 5]
# [4 3 1 2 5]

# %% [markdown]
# SEABORN MODULE

# %%
# sns.distplot([0,1,2,3,4,5])
# plt.show()

# %%
sns.distplot([0,1,2,3,4,5],hist=False)
plt.show()
# Out:
# C:\Users\guram\AppData\Local\Temp\ipykernel_5704\299229084.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5],hist=False)

# %% [markdown]
# NORMAL DISTRIBUTION

# %%
x = random.normal(loc=1, scale=2, size=(2,3))

print(x)
# Out:
# [[ 4.92455805  0.5997901   0.36568795]
#  [-0.08160358 -0.59226996  0.94205167]]

# %%
sns.distplot(random.normal(size=(1000)),hist=False)
# Out:
# C:\Users\guram\AppData\Local\Temp\ipykernel_6612\1312479887.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=(1000)),hist=False)
# <Axes: ylabel='Density'>

# %% [markdown]
# BINOMIAL DISTRIBUTION

# %%
x = random.binomial(n=10,p=0.5,size=1000)
print(x)
sns.distplot(x,hist=True, kde=False)
# Out:
# [4 6 6 6 6 3 7 3 3 6 3 7 6 3 6 6 7 5 6 4 5 4 6 7 8 7 5 4 8 6 5 3 5 6 9 8 7
#  5 4 5 7 1 3 3 5 3 7 8 6 5 5 3 2 6 7 4 1 6 2 5 9 4 6 2 7 3 7 6 4 5 4 7 5 3
#  6 3 5 3 6 3 5 4 5 3 8 6 4 7 7 5 7 6 6 6 7 4 8 4 8 9 6 5 7 4 5 8 7 3 3 5 5
#  6 6 7 6 3 2 8 6 5 4 5 7 4 4 5 5 6 2 3 6 4 2 7 8 5 5 3 1 3 7 4 3 3 6 7 2 8
#  8 6 8 8 6 7 5 2 2 5 4 2 3 2 8 3 4 6 3 4 9 5 6 5 1 4 7 5 7 5 4 7 8 7 4 4 3
#  7 5 4 5 7 7 6 4 5 4 3 5 3 4 5 7 5 3 6 6 6 5 3 7 6 6 3 2 6 7 6 4 4 4 5 6 4
#  5 7 7 3 3 6 4 4 7 7 4 6 5 7 6 6 6 5 5 4 6 2 4 4 6 4 4 3 7 4 6 4 8 7 7 7 6
#  6 6 6 8 8 6 3 8 5 5 6 5 8 4 7 6 7 4 4 8 8 7 5 4 4 6 6 6 5 5 3 4 5 5 5 6 7
#  5 4 6 6 7 4 3 6 7 6 5 7 4 6 5 4 6 5 7 4 4 3 5 6 6 4 5 7 4 3 7 5 5 4 5 5 5
#  5 5 2 3 6 3 8 4 3 3 5 6 6 8 4 4 6 6 3 2 2 6 5 3 6 5 7 6 6 5 6 5 3 5 5 4 2
#  3 4 4 3 5 4 5 6 6 5 4 6 7 7 5 6 4 4 8 4 5 4 5 6 6 6 5 3 4 6 4 6 6 6 5 7 9
#  4 4 3 5 6 7 5 7 5 8 3 6 4 3 5 4 5 6 6 3 4 3 7 6 4 5 6 4 3 3 3 4 5 4 8 4 4
# ...

# %%
sns.distplot(random.normal(loc=50, scale=5, size=1000),hist=False, label="normal")
sns.distplot(random.binomial(n=100,p=0.5,size=1000),hist=False, label="binomial")
plt.show()
# Out:
# C:\Users\guram\AppData\Local\Temp\ipykernel_6612\3978774152.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000),hist=False, label="normal")
# C:\Users\guram\AppData\Local\Temp\ipykernel_6612\3978774152.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# POISSON DISTRIBUTION

# %%
x= random.poisson(lam=2,size=1000)
print(x)
sns.distplot(x,kde=False)
# Out:
# [3 2 0 0 2 2 0 3 1 2 1 3 2 4 2 3 2 1 0 2 3 3 5 4 4 1 3 2 1 3 3 1 5 1 2 6 1
#  2 3 3 0 2 3 2 2 6 2 2 1 1 2 1 0 0 3 2 0 4 4 1 1 3 2 0 3 0 5 2 0 5 1 1 1 3
#  2 1 2 2 2 3 3 2 3 4 2 0 4 4 4 1 5 1 3 0 0 2 1 2 2 2 0 0 3 2 3 4 3 2 0 4 2
#  5 2 6 3 1 0 2 1 2 1 0 4 3 3 2 1 1 2 2 2 3 0 3 1 0 1 3 2 1 1 4 1 2 5 1 2 3
#  1 3 2 2 1 1 3 1 2 2 3 0 0 2 3 2 0 4 2 1 4 5 0 2 2 3 2 2 2 1 0 0 3 2 3 2 0
#  1 1 3 4 2 1 0 2 0 3 0 3 2 6 4 2 2 2 1 3 2 0 0 2 2 3 0 0 1 3 1 1 3 3 1 2 5
#  2 0 5 3 3 3 4 4 3 4 2 3 2 0 3 2 2 2 3 1 0 0 1 4 0 5 4 4 0 3 1 1 0 0 3 1 2
#  1 0 1 4 1 2 2 3 3 6 3 3 0 0 2 0 2 2 1 2 1 0 2 4 1 0 5 2 7 4 2 2 5 0 2 5 2
#  1 3 1 2 1 2 3 1 1 2 2 1 0 2 1 3 2 1 1 1 1 4 2 5 1 5 0 0 3 5 1 1 1 1 1 3 2
#  4 2 2 1 3 3 0 1 2 0 0 1 3 3 5 2 3 3 2 2 1 1 3 0 3 2 5 2 4 1 3 2 3 3 5 4 0
#  2 0 4 1 1 1 2 1 1 6 2 1 1 2 1 1 1 2 2 1 1 2 1 4 1 2 1 3 1 3 4 1 1 2 1 4 3
#  1 4 4 1 0 2 1 6 3 2 1 3 2 0 1 4 2 3 3 0 2 1 0 0 2 2 2 2 0 1 4 1 2 3 3 4 0
# ...

# %%
sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')

plt.show()
# Out:
# C:\Users\guram\AppData\Local\Temp\ipykernel_6612\2644614643.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
# C:\Users\guram\AppData\Local\Temp\ipykernel_6612\2644614643.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...
